# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 7 January 2022
#
# **Author**: Muklada
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %%
# check columns
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
# clean columns
cols = df.columns
clean_cols = [col.lower().replace(" ","_").replace("-","_") for col in cols]
df.columns = clean_cols
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>row_id</th>
#       <th>order_id</th>
#       <th>order_date</th>
#       <th>ship_date</th>
#       <th>ship_mode</th>
#       <th>customer_id</th>
#       <th>customer_name</th>
#       <th>segment</th>
#       <th>country/region</th>
#       <th>city</th>
#       <th>...</th>
#       <th>postal_code</th>
#       <th>region</th>
#       <th>product_id</th>
#       <th>category</th>
#       <th>sub_category</th>
#       <th>product_name</th>
#       <th>sales</th>
#       <th>quantity</th>
#       <th>discount</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# example of pd.to_datetime() function
pd.to_datetime(df['order_date'].head(), format='%m/%d/%Y')
# Out:
# <pre>0   2019-11-08
# 1   2019-11-08
# 2   2019-06-12
# 3   2018-10-11
# 4   2018-10-11
# Name: order_date, dtype: datetime64[ns]</pre>

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['order_date'] = pd.to_datetime(df['order_date'], format='%m/%d/%Y')
df['ship_date'] = pd.to_datetime(df['ship_date'], format='%m/%d/%Y')
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>row_id</th>
#       <th>order_id</th>
#       <th>order_date</th>
#       <th>ship_date</th>
#       <th>ship_mode</th>
#       <th>customer_id</th>
#       <th>customer_name</th>
#       <th>segment</th>
#       <th>country/region</th>
#       <th>city</th>
#       <th>...</th>
#       <th>postal_code</th>
#       <th>region</th>
#       <th>product_id</th>
#       <th>category</th>
#       <th>sub_category</th>
#       <th>product_name</th>
#       <th>sales</th>
#       <th>quantity</th>
#       <th>discount</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - count nan in postal code column
df['postal_code'].isna().sum()
# Out:
# 11

# %%
# TODO - filter rows with missing values
df[ df['postal_code'].isna() ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>row_id</th>
#       <th>order_id</th>
#       <th>order_date</th>
#       <th>ship_date</th>
#       <th>ship_mode</th>
#       <th>customer_id</th>
#       <th>customer_name</th>
#       <th>segment</th>
#       <th>country/region</th>
#       <th>city</th>
#       <th>...</th>
#       <th>postal_code</th>
#       <th>region</th>
#       <th>product_id</th>
#       <th>category</th>
#       <th>sub_category</th>
#       <th>product_name</th>
#       <th>sales</th>
#       <th>quantity</th>
#       <th>discount</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2234</th>
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions

# %% [markdown]
# **Q1**: Find overall, min and max sales gained in each state and grouped by region

# %%
df.groupby(['region','state'])['sales'].agg(['sum','min','max']).reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#       <th>state</th>
#       <th>sum</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Central</td>
#       <td>Illinois</td>
#       <td>80166.1010</td>
#       <td>0.836</td>
#       <td>2799.960</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Central</td>
#       <td>Indiana</td>
#       <td>53555.3600</td>
#       <td>1.980</td>
#       <td>17499.950</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Central</td>
#       <td>Iowa</td>
#       <td>4579.7600</td>
#       <td>5.400</td>
# ...

# %% [markdown]
# **Q2**: What are the 5 most profitable products sold in Michigan?

# %%
df[ df['state'] == 'Michigan' ].groupby('product_name')['profit'].sum()\
    .reset_index().sort_values('profit', ascending = False).head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>78</th>
#       <td>GBC Ibimaster 500 Manual ProClick Binding System</td>
#       <td>4946.3700</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>GBC DocuBind P400 Electric Binding System</td>
#       <td>2504.2216</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>Fellowes PB500 Electric Punch Plastic Comb Bin...</td>
#       <td>1906.4850</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>Maxell iVDR EX 500GB Cartridge</td>
#       <td>829.3754</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# **Ans**: 9994 rows and 21 columns

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
df.isna().sum()
# Out:
# <pre>row_id             0
# order_id           0
# order_date         0
# ship_date          0
# ship_mode          0
# customer_id        0
# customer_name      0
# segment            0
# country/region     0
# city               0
# state              0
# postal_code       11
# region             0
# product_id         0
# category           0
# sub_category       0
# product_name       0
# sales              0
# quantity           0
# discount           0
# profit             0
# dtype: int64</pre>

# %% [markdown]
# **Ans**: Yes, there are 11 missing values in 'postal_code' column.

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
result = df[ df['state'] == 'California' ]
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>row_id</th>
#       <th>order_id</th>
#       <th>order_date</th>
#       <th>ship_date</th>
#       <th>ship_mode</th>
#       <th>customer_id</th>
#       <th>customer_name</th>
#       <th>segment</th>
#       <th>country/region</th>
#       <th>city</th>
#       <th>...</th>
#       <th>postal_code</th>
#       <th>region</th>
#       <th>product_id</th>
#       <th>category</th>
#       <th>sub_category</th>
#       <th>product_name</th>
#       <th>sales</th>
#       <th>quantity</th>
#       <th>discount</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
# ...

# %%
result.to_csv("california_data.csv")

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file
result2 = df[ df['state'].isin(['California', 'Texas']) & (df['order_date'].dt.year == 2017) ]
result2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>row_id</th>
#       <th>order_id</th>
#       <th>order_date</th>
#       <th>ship_date</th>
#       <th>ship_mode</th>
#       <th>customer_id</th>
#       <th>customer_name</th>
#       <th>segment</th>
#       <th>country/region</th>
#       <th>city</th>
#       <th>...</th>
#       <th>postal_code</th>
#       <th>region</th>
#       <th>product_id</th>
#       <th>category</th>
#       <th>sub_category</th>
#       <th>product_name</th>
#       <th>sales</th>
#       <th>quantity</th>
#       <th>discount</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
# ...

# %%
result2.to_csv("friend_request.csv")

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
df[ df['order_date'].dt.year == 2017 ]['sales'].agg(['sum','mean','std'])
# Out:
# <pre>sum     484247.498100
# mean       242.974159
# std        754.053357
# Name: sales, dtype: float64</pre>

# %%
# TODO 06 - which Segment has the highest profit in 2018
df[ df['order_date'].dt.year == 2018 ].groupby('segment')['profit'].sum().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>segment</th>
#       <th>profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Consumer</td>
#       <td>28460.1665</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Corporate</td>
#       <td>20688.3248</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Home Office</td>
#       <td>12470.1124</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **Ans**: Consumer segment

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
df.query("order_date >= '2019-04-15' & order_date <= '2019-12-31'").groupby('state')\
    ['sales'].sum().sort_values().reset_index().head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>New Hampshire</td>
#       <td>49.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>New Mexico</td>
#       <td>64.08</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>District of Columbia</td>
#       <td>117.07</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Louisiana</td>
#       <td>249.80</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>South Carolina</td>
#       <td>502.48</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **Ans**: New Hapshire, Nex Mexico, District of Columbia, Louisiana and South Carolina

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 
df2 = df[ (df['order_date'].dt.year == 2019) ].groupby('region')['sales'].sum().reset_index()
df2['percentage'] = round(df2['sales'] * 100 / df2['sales'].sum(), 2)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#       <th>sales</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Central</td>
#       <td>147429.3760</td>
#       <td>24.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>East</td>
#       <td>180685.8220</td>
#       <td>29.66</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>South</td>
#       <td>93610.2235</td>
#       <td>15.37</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>West</td>
#       <td>187480.1765</td>
#       <td>30.77</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2[ df2['region'].isin(['Central','West']) ]['percentage'].sum()
# Out:
# 54.97

# %% [markdown]
# **Ans**: West and Central accounted for 54.97% of total sales in 2019

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

# %% [markdown]
# **Ans**: The following table shows the 10 most popular products sold in 2019-2020 in terms of quantity.

# %%
df[ df['order_date'].dt.year.isin([2019, 2020]) ].groupby('product_name')['quantity'].sum()\
    .sort_values(ascending=False).reset_index().head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Staples</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Easy-staple paper</td>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Staple envelope</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Staples in misc. colors</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Chromcraft Round Conference Tables</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %% [markdown]
# **Ans**: The following table shows the 10 most popular products sold in 2019-2020 in terms of sales.

# %%
df[ df['order_date'].dt.year.isin([2019, 2020]) ].groupby('product_name')['sales'].sum()\
    .sort_values(ascending=False).reset_index().head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_name</th>
#       <th>sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Canon imageCLASS 2200 Advanced Copier</td>
#       <td>61599.824</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Hewlett Packard LaserJet 3310 Copier</td>
#       <td>16079.732</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3D Systems Cube Printer, 2nd Generation, Magenta</td>
#       <td>14299.890</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>GBC Ibimaster 500 Manual ProClick Binding System</td>
#       <td>13621.542</td>
#     </tr>
#     <tr>
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

# %%
df['category'].value_counts().plot(kind='barh', color=['coral','mediumseagreen','deepskyblue']);

# %%
df[['sales','profit']].plot(x='sales', y='profit', kind='scatter', color='indianred');

# %%
df['ship_mode'].value_counts().plot(kind='pie', colors=['plum','khaki','lightgreen','cornflowerblue'])
# Out:
# <AxesSubplot:ylabel='ship_mode'>

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions

# %% [markdown]
# **Q1**: Name customers who are top buyers in terms of quantity in New York City

# %%
import numpy as np
df3 = df.query('city == "New York City"').groupby(['city','customer_name'])['quantity'].sum().reset_index()
df3['top_buyer'] = np.where(df3['quantity'] > 20, "Yes", "No")
df3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>customer_name</th>
#       <th>quantity</th>
#       <th>top_buyer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>New York City</td>
#       <td>Aaron Hawkins</td>
#       <td>6</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>New York City</td>
#       <td>Aaron Smayling</td>
#       <td>11</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>New York City</td>
#       <td>Adam Bellavance</td>
#       <td>12</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
df3[ df3['top_buyer'] == 'Yes' ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>city</th>
#       <th>customer_name</th>
#       <th>quantity</th>
#       <th>top_buyer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>New York City</td>
#       <td>Adam Shillingsburg</td>
#       <td>25</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>New York City</td>
#       <td>Ann Chong</td>
#       <td>40</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>New York City</td>
#       <td>Bart Watters</td>
#       <td>27</td>
#       <td>Yes</td>
#     </tr>
#     <tr>
#       <th>40</th>
# ...

# %% [markdown]
# **Q2**: Create Profit and Loss columns to identify each sub category's financial status

# %%
df4 = df.groupby('sub_category')['profit'].sum().reset_index()
df4['p&l'] = np.where(df4['profit'] > 0, "Profit", "Loss")
df4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sub_category</th>
#       <th>profit</th>
#       <th>p&amp;l</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Accessories</td>
#       <td>41936.6357</td>
#       <td>Profit</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Appliances</td>
#       <td>18138.0054</td>
#       <td>Profit</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Art</td>
#       <td>6527.7870</td>
#       <td>Profit</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Binders</td>
#       <td>30221.7633</td>
#       <td>Profit</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...
